# %% [markdown]
# # Listen to AudioAugmentation module

# %%
# %load_ext autoreload
# %autoreload 2

import os
import sys
sys.path.insert(1, os.path.join(sys.path[0], '..'))

from sslsv.data.AudioAugmentation import AudioAugmentation
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import numpy as np
import soundfile as sf
import IPython.display as ipd

# %%
class Config:
    enable = True
    musan = True
    rir = True
    musan_noise_snr = (0, 15)
    musan_speech_snr = (13, 20)
    musan_music_snr = (5, 15)
    
augmentation = AudioAugmentation(Config(), '../data/')

# %%
sample_path = '../data/voxceleb1/id10270/5r0dWxy17C8/00001.wav'

data, sr = sf.read(sample_path)
data = data.reshape((1, -1)).astype(np.float32)

ipd.Audio(data, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
data_aug = augmentation(data)
ipd.Audio(data_aug, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
data.shape, data_aug.shape
# Out:
# ((1, 133761), (1, 133761))
